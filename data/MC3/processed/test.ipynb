# %%
import json
import plotly.express as px
import numpy as np

# %%
file = open("07_2015_09_12.json", "r")
image_json = json.load(file)

print((image_json.keys()))
# Out:
# dict_keys(['date', 'RGB', 'plant_health', 'floods_or_burned', 'snow_ice_clouds', 'NDVI'])

# %%
image = np.array(image_json["RGB"], dtype=np.uint8)
fig = px.imshow(image)
fig.show()

# %%
img_rgb = np.array([[[255, 0, 0], [0, 255, 0], [0, 0, 255]],
					[[0, 255, 0], [0, 0, 255], [255, 0, 0]]
				   ], dtype=np.uint8)
print((img_rgb))		  
fig = px.imshow(img_rgb)
fig.show()
# Out:
# [[[255   0   0]
#   [  0 255   0]
#   [  0   0 255]]
#
#  [[  0 255   0]
#   [  0   0 255]
#   [255   0   0]]]
